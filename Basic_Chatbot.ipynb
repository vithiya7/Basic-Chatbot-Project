# %%
# Step 1: Define chatbot responses
def chatbot_reply(user_input):
    user_input = user_input.lower()

    if user_input == "hello":
        return "Hi there! 👋 Welcome to my chatbot."
    elif user_input == "how are you":
        return "I'm doing great, thanks for asking!"
    elif user_input == "bye":
        return "Goodbye! Have a nice day!"
    elif user_input == "help":
        return "You can try saying: hello, how are you, bye."
    else:
        return "Sorry, I don't understand that yet."

# Step 2: Main conversation loop
print("🤖 Chatbot: Hello! Type 'bye' to exit.")

while True:
    user_message = input("You: ")
    response = chatbot_reply(user_message)
    print("Chatbot:", response)

    if user_message.lower() == "bye":
        break
# Out:
# 🤖 Chatbot: Hello! Type 'bye' to exit.
# You: hello
# Chatbot: Hi there! 👋 Welcome to my chatbot.
# You: how are you
# Chatbot: I'm doing great, thanks for asking!
# You: help
# Chatbot: You can try saying: hello, how are you, bye.
# You: bye
# Chatbot: Goodbye! Have a nice day!
